# %% [markdown]
# # Деревья решений

# %% [markdown]
# Для выполнения домашнего задания необходимо взять файл boston house-prices datase (sklearn.datasets.load_boston) и построить модель.
# По аналогии задания к лекции «Классификация: Логистическая регрессия и SVM».
# А именно построить модель регрессии, дерево решений, оптимизировать параметры и сравнить результаты.

# %%
from sklearn.datasets import load_boston
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeRegressor
from matplotlib import pyplot as plt
from sklearn import tree

# %%
X, y = load_boston(return_X_y=True)    #загрузили выборку данных
X
# Out:
# array([[6.3200e-03, 1.8000e+01, 2.3100e+00, ..., 1.5300e+01, 3.9690e+02,
#         4.9800e+00],
#        [2.7310e-02, 0.0000e+00, 7.0700e+00, ..., 1.7800e+01, 3.9690e+02,
#         9.1400e+00],
#        [2.7290e-02, 0.0000e+00, 7.0700e+00, ..., 1.7800e+01, 3.9283e+02,
#         4.0300e+00],
#        ...,
#        [6.0760e-02, 0.0000e+00, 1.1930e+01, ..., 2.1000e+01, 3.9690e+02,
#         5.6400e+00],
#        [1.0959e-01, 0.0000e+00, 1.1930e+01, ..., 2.1000e+01, 3.9345e+02,
#         6.4800e+00],
#        [4.7410e-02, 0.0000e+00, 1.1930e+01, ..., 2.1000e+01, 3.9690e+02,
#         7.8800e+00]])

# %% [markdown]
# Попробуем обучить дерево без дополнительных параметров

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)
model = DecisionTreeRegressor()
model.fit(X_train, y_train)
# Out:
# DecisionTreeRegressor(criterion='mse', max_depth=None, max_features=None,
#                       max_leaf_nodes=None, min_impurity_decrease=0.0,
#                       min_impurity_split=None, min_samples_leaf=1,
#                       min_samples_split=2, min_weight_fraction_leaf=0.0,
#                       presort=False, random_state=None, splitter='best')

# %% [markdown]
# Модель переобучилась на обучающих данных

# %%
model.score(X_train, y_train)
# Out:
# 1.0

# %%
model.score(X_test,y_test)
# Out:
# 0.842397007497706

# %%
fig = plt.figure(figsize=(25,20))
_ = tree.plot_tree(model, filled=True)

# %% [markdown]
# Попробуем использовать параметры с урока

# %%
model = DecisionTreeRegressor(min_samples_leaf=9, criterion='mae')
model.fit(X_train, y_train)
# Out:
# DecisionTreeRegressor(criterion='mae', max_depth=None, max_features=None,
#                       max_leaf_nodes=None, min_impurity_decrease=0.0,
#                       min_impurity_split=None, min_samples_leaf=9,
#                       min_samples_split=2, min_weight_fraction_leaf=0.0,
#                       presort=False, random_state=None, splitter='best')

# %%
model.score(X_train, y_train)
# Out:
# 0.8193402570873857

# %%
model.score(X_test,y_test)
# Out:
# 0.8165908760762739

# %% [markdown]
# Качество не улучшилось

# %%
fig = plt.figure(figsize=(25,20))
_ = tree.plot_tree(model, filled=True)

# %% [markdown]
# Проверим при каком значении max_depth качество лучше. Будем приверять до 20. Здесь довольно сложно выбрать одно значение, т.к. при каждом запуске получаем разные значения качества

# %%
scores_on_train = []
scores_on_test = []
for i in range(3, 21):
    dt_regs = DecisionTreeRegressor(max_depth=i).fit(X_train, y_train)
    scores_on_train.append(dt_regs.score(X_train, y_train))
    scores_on_test.append(dt_regs.score(X_test, y_test))

# %%
deep = 2
for i, j in zip(scores_on_train, scores_on_test):
    deep += 1
    print(f"Deep = {deep}, Train score = {i}, Test score = {j}")
# Out:
# Deep = 3, Train score = 0.8251584424966962, Test score = 0.7435711616336519
# Deep = 4, Train score = 0.9018563786810155, Test score = 0.7255536066517965
# Deep = 5, Train score = 0.9277198621718044, Test score = 0.7903570763191351
# Deep = 6, Train score = 0.9478909478313639, Test score = 0.8533707997977932
# Deep = 7, Train score = 0.9688136380520931, Test score = 0.746400104802611
# Deep = 8, Train score = 0.9800398034333819, Test score = 0.7487964921278838
# Deep = 9, Train score = 0.9848565262719124, Test score = 0.850536456749335
# Deep = 10, Train score = 0.9886236755280331, Test score = 0.7512148245016977
# Deep = 11, Train score = 0.9923859690049794, Test score = 0.8460943427076335
# Deep = 12, Train score = 0.9955809062171125, Test score = 0.838735794830569
# Deep = 13, Train score = 0.9977698254854958, Test score = 0.7372637961036705
# Deep = 14, Train score = 0.998996899862784, Test score = 0.7429293214858845
# Deep = 15, Train score = 0.9993903315736662, Test score = 0.86263636837851
# Deep = 16, Train score = 0.9997510723530242, Test score = 0.7907590807684414
# Deep = 17, Train score = 0.9998989084861528, Test score = 0.8492935080570622
# Deep = 18, Train score = 0.9999811454390536, Test score = 0.7422282851803086
# Deep = 19, Train score = 0.9999993572308769, Test score = 0.8409613714743295
# Deep = 20, Train score = 1.0, Test score = 0.7607582318116757
